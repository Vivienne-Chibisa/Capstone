MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor

# %%
# Specify the path to your Excel file
file_path = r'C:\Users\hp\OneDrive - Saskatchewan Polytechnic\Desktop\Sask Poly\Semester 1.2\MidSem Report.xlsx'

# Read the Excel file
data = pd.read_excel(file_path)

data.head(5)
# Out:
#    YEAR  Farm Land( sq km)  employment in Agric, % of total employment  \
# 0  2000         612870.000                                    2.515509
# 1  2001         613081.608                                    2.160145
# 2  2002         620910.000                                    2.116887
# 3  2003         619460.000                                    2.107054
# 4  2004         618010.000                                    2.023169
#
#    population total Precipitation   Min temperature  Max temperature  \
# 0  30685730.0                344.6            -36.3             33.8
# 1  31020855.0              159.7              -35.0             37.7
# 2  31359199.0              299.3              -34.6             36.5
# 3  31642461.0              233.8              -38.3             38.6
# 4  31938807.0              402.6              -44.9             31.6
#
#    average temperature  Fertlizer  patent application non res  ...  \
# 0                  2.1  59.685851                     35435.0  ...
# 1                  3.8  60.420900                     35753.0  ...
# 2                  1.9  64.882359                     35782.0  ...
# 3                  2.7  66.667693                     33299.0  ...
# 4                  2.1  62.113345                     32970.0  ...
#
#    barley.production  Flaxseed( dollars per metric tonne)  flaxeseed.seed  \
# 0                NaN                           201.515000             NaN
# 1            10845.6                           265.327500             NaN
# 2            10845.6                           342.855000            29.6
# 3             7467.7                           336.719167            31.7
# 4            12164.2                           377.854167            29.7
#
#    flaxseed.production  \
# 0                  NaN
# 1                715.0
# 2                715.0
# 3                679.4
# 4                754.4
#
#    Canola (including rapeseed)( dollars per metric tonne)  seed requirement   \
# 0                                         233.605000                     NaN
# 1                                         280.780833                     NaN
# 2                                         353.843333                    27.9
# 3                                         346.510000                    34.1
# 4                                         342.473333                    37.6
#
#    canola.prodction  Lentils( dollars per metric tonne)  lentils seed req  \
# 0               NaN                          363.916667               NaN
# 1            5017.1                          301.250000               NaN
# 2            5017.1                          356.666667               NaN
# 3            4520.5                          452.500000               NaN
# 4            6771.2                          426.833333               NaN
#
#    lentils production
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# $$ Data Cleaning  $$

# %% [markdown]
# Data cleaning is a crucial step in the data analysis process for several reasons:
#
# Improves Data Quality: Cleaning ensures that the data is accurate, consistent, and reliable, which is essential for drawing valid conclusions.
# Removes Noise: By identifying and correcting errors, duplicates, and outliers, data cleaning reduces noise in the dataset, allowing for clearer insights.
# Enhances Model Performance: Clean data leads to better-performing models by minimizing biases and inaccuracies that can distort results.
# Facilitates Accurate Analysis: High-quality data allows for meaningful analysis, ensuring that the findings are reflective of the true underlying patterns in the data.
# Saves Time and Resources: Investing time in data cleaning upfront can save significant time and resources later by preventing issues during analysis and modeling stages.
# Supports Decision-Making: Clean data provides a solid foundation for making informed decisions, as stakeholders rely on accurate data for strategic planning and policy formulation.
#
# In summary, data cleaning is essential for ensuring data integrity, enhancing analytical outcomes, and supporting effective decision-making.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 32 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   YEAR                                                                           25 non-null     int64
#  1   Farm Land( sq km)                                                              22 non-null     float64
#  2   employment in Agric, % of total employment                                     24 non-null     float64
#  3   population                                                                     24 non-null     float64
#  4   total Precipitation                                                            25 non-null     object
#  5   Min temperature                                                                25 non-null     float64
#  6   Max temperature                                                                25 non-null     float64
#  7   average temperature                                                            25 non-null     float64
#  8   Fertlizer                                                                      23 non-null     float64
#  9   patent application non res                                                     22 non-null     float64
#  10  patent appl resi                                                               22 non-null     float64
#  11  soil types                                                                     0 non-null      float64
#  12  vegetation Greeness...Average normalized difference vegetation index (NDVI) 4  22 non-null     float64
#  13  urban greeness as a percentage                                                 21 non-null     float64
#  14  wheat ( dollars per metric tonne)                                              24 non-null     float64
#  15  wheat seed requirement                                                         24 non-null     float64
#  16  production                                                                     24 non-null     float64
#  17  Oats( dollars per metric tonne)                                                24 non-null     float64
#  18  oats. Seed req                                                                 23 non-null     float64
#  19  oats.production                                                                24 non-null     float64
#  20  Barley 6 7( dollars per metric tonne)                                          24 non-null     float64
#  21  barley.seed                                                                    23 non-null     float64
#  22  barley.production                                                              24 non-null     float64
#  23  Flaxseed( dollars per metric tonne)                                            24 non-null     float64
#  24  flaxeseed.seed                                                                 23 non-null     float64
#  25  flaxseed.production                                                            24 non-null     float64
#  26  Canola (including rapeseed)( dollars per metric tonne)                         24 non-null     float64
#  27  seed requirement                                                               23 non-null     float64
#  28  canola.prodction                                                               24 non-null     float64
#  29  Lentils( dollars per metric tonne)                                             24 non-null     float64
#  30  lentils seed req                                                               20 non-null     float64
#  31  lentils production                                                             20 non-null     float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
# Rename the columns
data.columns = [
    'Year', 'Farm_Area', 'Agric_Employment_Rate','Population', 'Precipitation', 
    'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons', 
    'Nonres_Pat_App', 'Res_Pat_App', 'Soil_Index', 
    'Veg_Greeness_Rate', 'Green_Ind', 'Wheat_Price', 
    'Wheat_Seed', 'Wheat_Prod', 'Oats_Price', 'Oats_Seed', 
    'Oats_Prod', 'Barley_Price', 'Barley_Seed', 'Barley_Prod', 
    'Flax_Price', 'Flax_Seed', 'Flax_Prod', 
    'Canola_Price', 'Canola_Seed', 'Canola_Prod', 
    'Lentils_Price', 'Lentils_Seed', 'Lentils_Prod'
]

# Display the first few rows of the updated dataset
data.head()
# Out:
#    Year   Farm_Area  Agric_Employment_Rate  Population Precipitation  \
# 0  2000  612870.000               2.515509  30685730.0         344.6
# 1  2001  613081.608               2.160145  31020855.0       159.7
# 2  2002  620910.000               2.116887  31359199.0       299.3
# 3  2003  619460.000               2.107054  31642461.0       233.8
# 4  2004  618010.000               2.023169  31938807.0       402.6
#
#    Min_Temp  Max_Temp  Ave_Temp  Fertlizer_Cons  Nonres_Pat_App  ...  \
# 0     -36.3      33.8       2.1       59.685851         35435.0  ...
# 1     -35.0      37.7       3.8       60.420900         35753.0  ...
# 2     -34.6      36.5       1.9       64.882359         35782.0  ...
# 3     -38.3      38.6       2.7       66.667693         33299.0  ...
# 4     -44.9      31.6       2.1       62.113345         32970.0  ...
#
#    Barley_Prod  Flax_Price  Flax_Seed  Flax_Prod  Canola_Price  Canola_Seed  \
# 0          NaN  201.515000        NaN        NaN    233.605000          NaN
# 1      10845.6  265.327500        NaN      715.0    280.780833          NaN
# 2      10845.6  342.855000       29.6      715.0    353.843333         27.9
# 3       7467.7  336.719167       31.7      679.4    346.510000         34.1
# 4      12164.2  377.854167       29.7      754.4    342.473333         37.6
#
#    Canola_Prod  Lentils_Price  Lentils_Seed  Lentils_Prod
# 0          NaN     363.916667           NaN           NaN
# 1       5017.1     301.250000           NaN           NaN
# 2       5017.1     356.666667           NaN           NaN
# 3       4520.5     452.500000           NaN           NaN
# 4       6771.2     426.833333           NaN           NaN
#
# [5 rows x 32 columns]

# %%
# Check if the column 'Soil_Index' exists and is empty
if 'Soil_Index' in data.columns and data['Soil_Index'].isnull().all():
    # Drop the empty column
    data = data.drop(columns=['Soil_Index'])

# Optionally, you can print the DataFrame to verify the column has been removed
data.head()
# Out:
#    Year   Farm_Area  Agric_Employment_Rate  Population Precipitation  \
# 0  2000  612870.000               2.515509  30685730.0         344.6
# 1  2001  613081.608               2.160145  31020855.0       159.7
# 2  2002  620910.000               2.116887  31359199.0       299.3
# 3  2003  619460.000               2.107054  31642461.0       233.8
# 4  2004  618010.000               2.023169  31938807.0       402.6
#
#    Min_Temp  Max_Temp  Ave_Temp  Fertlizer_Cons  Nonres_Pat_App  ...  \
# 0     -36.3      33.8       2.1       59.685851         35435.0  ...
# 1     -35.0      37.7       3.8       60.420900         35753.0  ...
# 2     -34.6      36.5       1.9       64.882359         35782.0  ...
# 3     -38.3      38.6       2.7       66.667693         33299.0  ...
# 4     -44.9      31.6       2.1       62.113345         32970.0  ...
#
#    Barley_Prod  Flax_Price  Flax_Seed  Flax_Prod  Canola_Price  Canola_Seed  \
# 0          NaN  201.515000        NaN        NaN    233.605000          NaN
# 1      10845.6  265.327500        NaN      715.0    280.780833          NaN
# 2      10845.6  342.855000       29.6      715.0    353.843333         27.9
# 3       7467.7  336.719167       31.7      679.4    346.510000         34.1
# 4      12164.2  377.854167       29.7      754.4    342.473333         37.6
#
#    Canola_Prod  Lentils_Price  Lentils_Seed  Lentils_Prod
# 0          NaN     363.916667           NaN           NaN
# 1       5017.1     301.250000           NaN           NaN
# 2       5017.1     356.666667           NaN           NaN
# 3       4520.5     452.500000           NaN           NaN
# 4       6771.2     426.833333           NaN           NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Fill the null values using the Multivariate Imputation by Chained Equations (MICE)
#
# Multivariate Imputation by Chained Equations (MICE) is a sophisticated statistical technique used to handle missing data by leveraging the relationships among multiple variables. The method begins by making initial guesses for the missing values, often using simple imputation techniques like mean or median. It then iteratively refines these guesses by treating each variable with missing data as a dependent variable, predicting its values based on the other observed variables in the dataset. This predictive modeling is typically carried out using regression techniques or other suitable algorithms. After each iteration, the imputed values are updated, and the process continues until the estimates converge or a specified number of iterations is reached. By incorporating the dependencies among variables, MICE provides more accurate and plausible imputed values, enabling better data analysis and interpretation while preserving the inherent relationships in the dataset.
#
# Advantages of MICE
# Preserves Relationships: MICE takes into account the relationships between variables, leading to more plausible imputations.
# Flexibility: It can handle different types of data (continuous, categorical) and allows for various models to be used for imputation.
# Multiple Imputation: MICE can produce multiple imputed datasets, allowing for uncertainty in the imputation to be accounted for in analyses.

# %%
# Initialize the Iterative Imputer
imputer = IterativeImputer(random_state=0)

# Fit the imputer on the data and transform it
data = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# Check for any remaining NaN values
data.isnull().sum()
# Out:
# Year                     0
# Farm_Area                0
# Agric_Employment_Rate    0
# Population               0
# Precipitation            0
# Min_Temp                 0
# Max_Temp                 0
# Ave_Temp                 0
# Fertlizer_Cons           0
# Nonres_Pat_App           0
# Res_Pat_App              0
# Veg_Greeness_Rate        0
# Green_Ind                0
# Wheat_Price              0
# Wheat_Seed               0
# Wheat_Prod               0
# Oats_Price               0
# Oats_Seed                0
# Oats_Prod                0
# Barley_Price             0
# Barley_Seed              0
# Barley_Prod              0
# Flax_Price               0
# Flax_Seed                0
# Flax_Prod                0
# Canola_Price             0
# Canola_Seed              0
# Canola_Prod              0
# Lentils_Price            0
# Lentils_Seed             0
# Lentils_Prod             0
# dtype: int64

# %%
# Check for duplicates
duplicates = data.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicates.sum()

# Display the number of duplicate rows
print(f'Number of duplicate rows: {num_duplicates}')

# Optionally, to see the duplicate rows themselves:
duplicate_rows = data[duplicates]
print('Duplicate rows:')
print(duplicate_rows)
# Out:
# Number of duplicate rows: 0
# Duplicate rows:
# Empty DataFrame
# Columns: [Year, Farm_Area, Agric_Employment_Rate, Population, Precipitation, Min_Temp, Max_Temp, Ave_Temp, Fertlizer_Cons, Nonres_Pat_App, Res_Pat_App, Veg_Greeness_Rate, Green_Ind, Wheat_Price, Wheat_Seed, Wheat_Prod, Oats_Price, Oats_Seed, Oats_Prod, Barley_Price, Barley_Seed, Barley_Prod, Flax_Price, Flax_Seed, Flax_Prod, Canola_Price, Canola_Seed, Canola_Prod, Lentils_Price, Lentils_Seed, Lentils_Prod]
# Index: []
#
# [0 rows x 31 columns]

# %%
data['Year'] = data['Year'].astype(int)

# Now set 'Year' as the index
data.set_index('Year', inplace=True)

# Display the updated DataFrame
print("\nUpdated DataFrame with 'Year' as index:")
data.head(5)
# Out:
# Updated DataFrame with 'Year' as index:
#        Farm_Area  Agric_Employment_Rate  Population  Precipitation  Min_Temp  \
# Year
# 2000  612870.000               2.515509  30685730.0          344.6     -36.3
# 2001  613081.608               2.160145  31020855.0          159.7     -35.0
# 2002  620910.000               2.116887  31359199.0          299.3     -34.6
# 2003  619460.000               2.107054  31642461.0          233.8     -38.3
# 2004  618010.000               2.023169  31938807.0          402.6     -44.9
#
#       Max_Temp  Ave_Temp  Fertlizer_Cons  Nonres_Pat_App  Res_Pat_App  ...  \
# Year                                                                   ...
# 2000      33.8       2.1       59.685851         35435.0       4187.0  ...
# 2001      37.7       3.8       60.420900         35753.0       3963.0  ...
# 2002      36.5       1.9       64.882359         35782.0       3959.0  ...
# 2003      38.6       2.7       66.667693         33299.0       3929.0  ...
# 2004      31.6       2.1       62.113345         32970.0       5231.0  ...
#
#        Barley_Prod  Flax_Price  Flax_Seed  Flax_Prod  Canola_Price  \
# Year
# 2000  10364.729096  201.515000  31.038438  813.49607    233.605000
# 2001  10845.600000  265.327500  31.241273  715.00000    280.780833
# 2002  10845.600000  342.855000  29.600000  715.00000    353.843333
# 2003   7467.700000  336.719167  31.700000  679.40000    346.510000
# 2004  12164.200000  377.854167  29.700000  754.40000    342.473333
#
#       Canola_Seed  Canola_Prod  Lentils_Price  Lentils_Seed  Lentils_Prod
# Year
# 2000    36.698483  5917.291739     363.916667     44.391345    580.177192
# 2001    34.798516  5017.100000     301.250000     44.435824    533.463402
# 2002    27.900000  5017.100000     356.666667     52.581900    613.145093
# 2003    34.100000  4520.500000     452.500000     66.191259    625.478338
# 2004    37.600000  6771.200000     426.833333     63.503027    858.966085
#
# [5 rows x 30 columns]

# %% [markdown]
# In the next line of code, I perform a corelation test on the dataset to understand the relationships between different variables, especially focusing on specific output columns related to crop production.
# In summary, correlation testing is a foundational step in exploratory data analysis that informs subsequent modeling decisions, enhances understanding of the data and ensures the robustness of analytical approaches.

# %%
# List of output columns
output_columns = ['Wheat_Prod', 'Oats_Prod', 'Barley_Prod', 'Flax_Prod', 'Canola_Prod', 'Lentils_Prod']

# Calculate the correlation matrix for all variables
correlation_matrix = data.corr()

# Extract correlations with respect to the output columns
output_correlations = correlation_matrix[output_columns]

output_correlations
# Out:
#                        Wheat_Prod  Oats_Prod  Barley_Prod  Flax_Prod  \
# Farm_Area               -0.724676  -0.336250     0.488043   0.470669
# Agric_Employment_Rate   -0.726082  -0.313725     0.417787   0.582673
# Population               0.756634   0.409690    -0.419043  -0.512027
# Precipitation           -0.125213  -0.143961     0.290897   0.304718
# Min_Temp                -0.096339  -0.070195    -0.123941   0.290861
# Max_Temp                -0.055942   0.240537    -0.190393  -0.165112
# Ave_Temp                 0.048588  -0.093505    -0.112499   0.123744
# Fertlizer_Cons           0.762507   0.367283    -0.471809  -0.581088
# Nonres_Pat_App          -0.557821  -0.051332     0.541842   0.490941
# Res_Pat_App             -0.062584   0.276048     0.504494   0.137090
# Veg_Greeness_Rate       -0.519891  -0.481579     0.062954   0.305264
# Green_Ind               -0.350351  -0.246585     0.016988   0.264181
# Wheat_Price              0.327142   0.358130    -0.451133  -0.516924
# Wheat_Seed              -0.077436  -0.024145     0.089663  -0.018129
# Wheat_Prod               1.000000   0.442899    -0.047260  -0.259641
# Oats_Price               0.279601   0.153297    -0.440145  -0.563187
# Oats_Seed               -0.695106  -0.209532     0.429855   0.390604
# Oats_Prod                0.442899   1.000000     0.386984   0.043928
# Barley_Price             0.504557   0.304182    -0.531231  -0.560821
# Barley_Seed             -0.701428  -0.091490     0.491271   0.329262
# Barley_Prod             -0.047260   0.386984     1.000000   0.317342
# Flax_Price               0.339576   0.236545    -0.372755  -0.593202
# Flax_Seed               -0.570843  -0.101297     0.547370   0.589417
# Flax_Prod               -0.259641   0.043928     0.317342   1.000000
# Canola_Price             0.386818   0.283659    -0.480164  -0.570350
# Canola_Seed              0.762032   0.270220    -0.537851  -0.477514
# Canola_Prod              0.863066   0.348649    -0.389888  -0.369412
# Lentils_Price            0.352396   0.358348    -0.322184  -0.152043
# Lentils_Seed             0.623620   0.145619    -0.488103  -0.280551
# Lentils_Prod             0.763264   0.271020    -0.380479  -0.312041
#
#                        Canola_Prod  Lentils_Prod
# Farm_Area                -0.868557     -0.784036
# Agric_Employment_Rate    -0.836082     -0.759751
# Population                0.899510      0.832905
# Precipitation            -0.217164     -0.258505
# Min_Temp                 -0.092629     -0.012070
# Max_Temp                  0.013052      0.027602
# Ave_Temp                  0.073453      0.227992
# Fertlizer_Cons            0.876212      0.823335
# Nonres_Pat_App           -0.703458     -0.700163
# Res_Pat_App              -0.186831     -0.258510
# Veg_Greeness_Rate        -0.469071     -0.456836
# Green_Ind                -0.389126     -0.427996
# Wheat_Price               0.496791      0.428713
# Wheat_Seed               -0.125668     -0.128303
# Wheat_Prod                0.863066      0.763264
# Oats_Price                0.424169      0.384980
# Oats_Seed                -0.831084     -0.779599
# Oats_Prod                 0.348649      0.271020
# Barley_Price              0.662554      0.590686
# Barley_Seed              -0.875366     -0.827243
# Barley_Prod              -0.389888     -0.380479
# Flax_Price                0.494850      0.453282
# Flax_Seed                -0.751211     -0.682916
# Flax_Prod                -0.369412     -0.312041
# Canola_Price              0.561525      0.523116
# Canola_Seed               0.942038      0.872059
# Canola_Prod               1.000000      0.925758
# Lentils_Price             0.526925      0.511227
# Lentils_Seed              0.852001      0.856270
# Lentils_Prod              0.925758      1.000000

# %%
correlation_matrix = data.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
data.head()
# Out:
#        Farm_Area  Agric_Employment_Rate  Population  Precipitation  Min_Temp  \
# Year
# 2000  612870.000               2.515509  30685730.0          344.6     -36.3
# 2001  613081.608               2.160145  31020855.0          159.7     -35.0
# 2002  620910.000               2.116887  31359199.0          299.3     -34.6
# 2003  619460.000               2.107054  31642461.0          233.8     -38.3
# 2004  618010.000               2.023169  31938807.0          402.6     -44.9
#
#       Max_Temp  Ave_Temp  Fertlizer_Cons  Nonres_Pat_App  Res_Pat_App  ...  \
# Year                                                                   ...
# 2000      33.8       2.1       59.685851         35435.0       4187.0  ...
# 2001      37.7       3.8       60.420900         35753.0       3963.0  ...
# 2002      36.5       1.9       64.882359         35782.0       3959.0  ...
# 2003      38.6       2.7       66.667693         33299.0       3929.0  ...
# 2004      31.6       2.1       62.113345         32970.0       5231.0  ...
#
#        Barley_Prod  Flax_Price  Flax_Seed  Flax_Prod  Canola_Price  \
# Year
# 2000  10364.729096  201.515000  31.038438  813.49607    233.605000
# 2001  10845.600000  265.327500  31.241273  715.00000    280.780833
# 2002  10845.600000  342.855000  29.600000  715.00000    353.843333
# 2003   7467.700000  336.719167  31.700000  679.40000    346.510000
# 2004  12164.200000  377.854167  29.700000  754.40000    342.473333
#
#       Canola_Seed  Canola_Prod  Lentils_Price  Lentils_Seed  Lentils_Prod
# Year
# 2000    36.698483  5917.291739     363.916667     44.391345    580.177192
# 2001    34.798516  5017.100000     301.250000     44.435824    533.463402
# 2002    27.900000  5017.100000     356.666667     52.581900    613.145093
# 2003    34.100000  4520.500000     452.500000     66.191259    625.478338
# 2004    37.600000  6771.200000     426.833333     63.503027    858.966085
#
# [5 rows x 30 columns]

# %% [markdown]
# $$ Eploratory Data Analysis $$

# %% [markdown]
# Now that we have dealt with missing values and checked the relevance of our data, we move on to EDA.
#
# In my project, which focuses on agricultural production and various influencing factors, Exploratory Data Analysis (EDA) is particularly important for several reasons, including but not limited to
# Understanding Data Structure: EDA allows me to explore the dataset containing variables such as crop yields, weather conditions, and agricultural practices (e.g., Fertilizer_Cons). By examining the types of data and their distributions, I can better understand how these factors interact and influence crop production.
# Uncovering Patterns and Trends: By visualizing relationships between variables, EDA helps discover underlying trends and correlations. This insight is essential for formulating hypotheses about what factors most significantly influence agricultural productivity.
# Informing Feature Selection: Understanding the correlations among variables allows you to identify which predictors are most relevant to crop yields. For instance, if I find a strong correlation between Fertilizer_Cons and precipitation, you might decide to focus on these variables in your predictive modeling.
#
# In summary, EDA is vital as it lays the groundwork for accurate analysis, helps me understand complex interactions in agricultural data, and ultimately leads to more reliable and actionable insights regarding crop production and influencing factors.

# %%
plt.figure(figsize=(14, 7))

# Plotting each crop's production using the index for the x-axis
plt.plot(data.index, data['Wheat_Prod'], label='Wheat Production', marker='o')
plt.plot(data.index, data['Oats_Prod'], label='Oats Production', marker='o')
plt.plot(data.index, data['Barley_Prod'], label='Barley Production', marker='o')
plt.plot(data.index, data['Flax_Prod'], label='Flax Production', marker='o')
plt.plot(data.index, data['Canola_Prod'], label='Canola Production', marker='o')
plt.plot(data.index, data['Lentils_Prod'], label='Lentils Production', marker='o')

# Adding titles and labels
plt.title('Crop Production Over Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Production', fontsize=12)
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %%
# Calculate the sum of all crop productions
data['Total_Prod'] = data['Wheat_Prod'] + data['Oats_Prod'] + data['Barley_Prod'] + data['Flax_Prod'] + data['Canola_Prod'] + data['Lentils_Prod']

plt.figure(figsize=(14, 7))

# Plotting total crop production using the index for the x-axis
plt.plot(data.index, data['Total_Prod'], marker='o', color='blue', label='Total Crop Production')

# Adding an imaginary axis for employment rate
employment_rate_scaled = data['Agric_Employment_Rate'] * (data['Total_Prod'].max() / data['Agric_Employment_Rate'].max())
plt.plot(data.index, employment_rate_scaled, marker='o', color='orange', linestyle='--', label='Employment Rate (scaled)')

# Optionally, adding farm area with scaling
farm_area_scaled = data['Farm_Area'] * (data['Total_Prod'].max() / data['Farm_Area'].max())
plt.plot(data.index, farm_area_scaled, marker='o', color='green', linestyle='--', label='Farm Area (scaled)')

# Adding titles and labels
plt.title('Total Crop Production, Agricultural Employment Rate and Total Farm Area Over Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Crop Production', fontsize=12, color='blue')

# Create a second y-axis for the employment rate label
ax2 = plt.gca().twinx()  
ax2.set_ylabel('Agricultural Employment Rate (scaled)', fontsize=12, color='orange')

# Adding grid and legend
plt.grid()
plt.legend(loc='upper left')

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Set the style
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
scatter_plot = sns.scatterplot(data=data, x='Fertlizer_Cons', y='Precipitation', color='blue')

# Add a trend line
sns.regplot(data=data, x='Fertlizer_Cons', y='Precipitation', scatter=False, color='orange')

# Set the title and labels
plt.title('Relationship Between Fertilizer Consumption and Precipitation', fontsize=16)
plt.xlabel('Fertilizer Consumption (kg/ha)', fontsize=14)
plt.ylabel('Precipitation (mm)', fontsize=14)

# Show the plot
plt.show()

# %%
# Set the figure and axes
fig, ax = plt.subplots(figsize=(12, 6))

# Bar plot for average temperature and precipitation
sns.barplot(data=data, x=data.index, y='Ave_Temp', color='skyblue', ax=ax, label='Average Temperature')
sns.barplot(data=data, x=data.index, y='Precipitation', color='lightgreen', ax=ax, label='Precipitation', alpha=0.6)

# Set titles and labels
ax.set_title('Average Temperature and Precipitation', fontsize=16)
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Temperature (°C) / Precipitation (mm)', fontsize=14)

# Show legends
ax.legend(loc='upper left')

# Show the plot
plt.show()

# %%
# Split the data into training (80%) and testing (20%) sets
train, test = train_test_split(data, test_size=0.2, random_state=42)

# Print the shapes of the training and testing sets
print("Training set shape:", train.shape)
print("Testing set shape:", test.shape)
# Out:
# Training set shape: (20, 31)
# Testing set shape: (5, 31)

# %%
# Define crops information
crops_info = {
    'Wheat': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Wheat_Prod',
        'seed_var': 'Wheat_Seed',
        'price_var': 'Wheat_Price'
    },
    'Oats': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Oats_Prod',
        'seed_var': 'Oats_Seed',
        'price_var': 'Oats_Price'
    },
    'Barley': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Barley_Prod',
        'seed_var': 'Barley_Seed',
        'price_var': 'Barley_Price'
    },
    'Flax': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Flax_Prod',
        'seed_var': 'Flax_Seed',
        'price_var': 'Flax_Price'
    },
    'Canola': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Canola_Prod',
        'seed_var': 'Canola_Seed',
        'price_var': 'Canola_Price'
    },
    'Lentils': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Lentils_Prod',
        'seed_var': 'Lentils_Seed',
        'price_var': 'Lentils_Price'
    }
}

# %% [markdown]
# $$ MODEL BUILDING   $$

# %% [markdown]
# 1. LINEAR REGRESSION
#
#    Why Linear Regression?
# Simplicity and Interpretability:
# Linear regression is straightforward to interpret. It estimates the relationship between the input features and the target variable by fitting a linear equation, making it intuitive to understand how changes in the features affect the target.
# Efficiency:
# Linear regression is computationally efficient, making it suitable for large datasets. It requires less computational power than more complex models like SVR or neural networks.
# Linear Relationships:
# If the relationship between the features and the target variable is approximately linear, linear regression can provide good predictive performance.
# Baseline Model:
# It serves as a good baseline model against which the performance of more complex algorithms can be compared. If the linear model performs well, there may be no need to use more complicated approaches.
# Common in Agriculture:
# In agricultural contexts, relationships between factors like area, employment, and production are often linear or can be approximated as linear, making linear regression a suitable choice.
#
# Using linear regression in this context allows for a straightforward analysis of how various factors influence crop production. Later, we will explore more complex models like SVR or random forests. This approach ensures that we start with a model that is easy to understand and interpret before moving on to more sophisticated techniques.

# %%
def train_crop_model(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize and fit the linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name}:')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model using train and test sets
for crop, info in crops_info.items():
    train_crop_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
# Out:
# Model for Wheat:
# Mean Squared Error: 36968230.22269744
# R^2 Score: -0.7857490920259824
# Mean Absolute Error (MAE): 4769.484515104051
# ---
# Model for Oats:
# Mean Squared Error: 557090.5917899926
# R^2 Score: 0.47586950855195087
# Mean Absolute Error (MAE): 715.7317433630808
# ---
# Model for Barley:
# Mean Squared Error: 7308276.389667344
# R^2 Score: -3.5674490117239195
# Mean Absolute Error (MAE): 2132.7947110232003
# ---
# Model for Flax:
# Mean Squared Error: 461343.40596996807
# R^2 Score: -10.676084947345231
# Mean Absolute Error (MAE): 543.9133055112364
# ---
# Model for Canola:
# Mean Squared Error: 7146620.561907354
# R^2 Score: 0.7135897804994502
# Mean Absolute Error (MAE): 2267.4770481738437
# ---
# Model for Lentils:
# Mean Squared Error: 271204.4610941615
# R^2 Score: 0.5970370694324089
# Mean Absolute Error (MAE): 414.81558108498905
# ---

# %%
data.head()
# Out:
#        Farm_Area  Agric_Employment_Rate  Population  Precipitation  Min_Temp  \
# Year
# 2000  612870.000               2.515509  30685730.0          344.6     -36.3
# 2001  613081.608               2.160145  31020855.0          159.7     -35.0
# 2002  620910.000               2.116887  31359199.0          299.3     -34.6
# 2003  619460.000               2.107054  31642461.0          233.8     -38.3
# 2004  618010.000               2.023169  31938807.0          402.6     -44.9
#
#       Max_Temp  Ave_Temp  Fertlizer_Cons  Nonres_Pat_App  Res_Pat_App  ...  \
# Year                                                                   ...
# 2000      33.8       2.1       59.685851         35435.0       4187.0  ...
# 2001      37.7       3.8       60.420900         35753.0       3963.0  ...
# 2002      36.5       1.9       64.882359         35782.0       3959.0  ...
# 2003      38.6       2.7       66.667693         33299.0       3929.0  ...
# 2004      31.6       2.1       62.113345         32970.0       5231.0  ...
#
#       Flax_Price  Flax_Seed  Flax_Prod  Canola_Price  Canola_Seed  \
# Year
# 2000  201.515000  31.038438  813.49607    233.605000    36.698483
# 2001  265.327500  31.241273  715.00000    280.780833    34.798516
# 2002  342.855000  29.600000  715.00000    353.843333    27.900000
# 2003  336.719167  31.700000  679.40000    346.510000    34.100000
# 2004  377.854167  29.700000  754.40000    342.473333    37.600000
#
#       Canola_Prod  Lentils_Price  Lentils_Seed  Lentils_Prod    Total_Prod
# Year
# 2000  5917.291739     363.916667     44.391345    580.177192  37651.007537
# 2001  5017.100000     301.250000     44.435824    533.463402  37382.563402
# 2002  5017.100000     356.666667     52.581900    613.145093  37462.245093
# 2003  4520.500000     452.500000     66.191259    625.478338  28288.178338
# 2004  6771.200000     426.833333     63.503027    858.966085  42762.466085
#
# [5 rows x 31 columns]

# %%
# Define features and target variable for the Canola crop
X_train = train[['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                  'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                  'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                  'Canola_Seed', 'Canola_Price']]
y_train = train['Canola_Prod']

X_test = test[['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                'Canola_Seed', 'Canola_Price']]
y_test = test['Canola_Prod']

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Make predictions for the entire dataset using the already trained model
y_pred_all = model.predict(data[['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                                   'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                                   'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                                   'Canola_Seed', 'Canola_Price']])

# Create a DataFrame to hold actual and predicted values
results_df = pd.DataFrame({
    'Actual_Canola_Prod': data['Canola_Prod'],
    'Predicted_Canola_Prod': y_pred_all
}, index=data.index)  # Use the existing index (Year)

# Sort by Year (if needed)
results_df.sort_index(inplace=True)

# Reset index if you want 'Year' as a column
results_df.reset_index(inplace=True)
results_df.rename(columns={'index': 'Year'}, inplace=True)

# Display the results
results_df
# Out:
#     Year  Actual_Canola_Prod  Predicted_Canola_Prod
# 0   2000         5917.291739            6768.287837
# 1   2001         5017.100000            5612.091837
# 2   2002         5017.100000            4401.671991
# 3   2003         4520.500000            4463.694355
# 4   2004         6771.200000            6119.878124
# 5   2005         7673.600000            8838.337165
# 6   2006         9483.300000            8922.356332
# 7   2007         9000.300000            9585.919869
# 8   2008         9611.100000           10018.557248
# 9   2009        12644.900000           12533.718843
# 10  2010        12898.100000           12876.324073
# 11  2011        12788.600000           10010.356753
# 12  2012        14608.100000           14280.668304
# 13  2013        13868.500000           14174.490023
# 14  2014        18551.000000           18209.593522
# 15  2015        16410.100000           15911.982553
# 16  2016        18376.500000           15213.097221
# 17  2017        19599.200000           19489.274477
# 18  2018        21458.100000           21450.114733
# 19  2019        20723.500000           20920.496824
# 20  2020        19912.300000           19786.525646
# 21  2021        19484.700000           18891.340229
# 22  2022        14248.300000           14747.064284
# 23  2023        18849.800000           22987.085869
# 24  2024        19191.700000           19866.056817

# %%
# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(results_df['Year'], results_df['Actual_Canola_Prod'], label='Actual Canola Production', color='blue', marker='o')
plt.plot(results_df['Year'], results_df['Predicted_Canola_Prod'], label='Predicted Canola Production', color='orange', marker='x')

# Add titles and labels
plt.title('Actual vs. Predicted Canola Production')
plt.xlabel('Year')
plt.ylabel('Canola Production')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.grid()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# $$ Ridge and Lasso Regressions $$

# %% [markdown]
# Ridge Regression:
#
# Handling Multicollinearity: Effective for situations where independent variables are highly correlated, stabilizing coefficient estimates.
# Regularization: Employs L2 regularization, discouraging large coefficients and helping to prevent overfitting, especially in high-dimensional datasets.
# Improved Generalization: Constrains coefficients to enhance the model’s ability to generalize to unseen data, reducing the risk of overfitting.
# Preservation of All Features: Retains all features in the model, making it suitable when all predictors are believed to contribute to the outcome.
# Tuning with Alpha: The alpha parameter controls the strength of the penalty, allowing for a balance between model complexity and performance.
# Conclusion: Ridge regression is a robust technique for linear modeling, particularly beneficial in handling multicollinearity and high-dimensional datasets, while effectively preventing overfitting.
#
# Lasso Regression:
#
# Feature Selection: Shrinks some coefficients to zero, eliminating less important variables and simplifying the model.
# Simplicity: Results in simpler models that are easier to interpret and communicate, enhancing robustness.
# Handling Multicollinearity: Effective in scenarios with correlated variables, potentially removing some entirely to clarify key features.
# Regularization: Uses L1 regularization to promote sparsity, leading to models that are less complex and more generalizable.
# Lasso regression is valuable for feature selection, simplicity, and handling multicollinearity, with the ability to fine-tune model performance through the alpha parameter.le for feature selection, simplicity, and handling multicollinearity, with the ability to fine-tune model performance through the alpha parameter.
# Tuning with Alpha: The alpha parameter determines the strength of the penalty; setting it to 1.0 applies a moderate level of regularization, balancing model fit and complexity.
#
# Explanation of Alpha=1.0:
#
# Indicates a balanced regularization approach, retaining important predictors while mitigating overfitting. Adjusting alpha can optimize the model for better predictions and interpretability.
# ugh the alpha parameter.

# %%
def train_crop_model(train, test, crop_name, features, target, seed_var, price_var, alpha=1.0):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize and fit the ridge regression model
    model = Ridge(alpha=alpha)
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Ridge Regression with alpha {alpha}):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model with ridge regression
for crop, info in crops_info.items():
    train_crop_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'], alpha=1.0)
# Out:
# Model for Wheat (Ridge Regression with alpha 1.0):
# Mean Squared Error: 22061732.97271739
# R^2 Score: -0.06569125400980913
# Mean Absolute Error (MAE): 4134.429524736157
# ---
# Model for Oats (Ridge Regression with alpha 1.0):
# Mean Squared Error: 1198309.3384347274
# R^2 Score: -0.12741172031378523
# Mean Absolute Error (MAE): 931.8454650117061
# ---
# Model for Barley (Ridge Regression with alpha 1.0):
# Mean Squared Error: 12612903.156109398
# R^2 Score: -6.88267834763206
# Mean Absolute Error (MAE): 2944.807943059391
# ---
# Model for Flax (Ridge Regression with alpha 1.0):
# Mean Squared Error: 76154.57307029457
# R^2 Score: -0.9273869590225641
# Mean Absolute Error (MAE): 204.89459486235947
# ---
# Model for Canola (Ridge Regression with alpha 1.0):
# Mean Squared Error: 1847924.4498200647
# R^2 Score: 0.9259419969608486
# Mean Absolute Error (MAE): 1227.0322958152854
# ---
# Model for Lentils (Ridge Regression with alpha 1.0):
# Mean Squared Error: 335377.9530096456
# R^2 Score: 0.5016863577859632
# Mean Absolute Error (MAE): 461.7061800565631
# ---

# %%
def train_crop_model(train, test, crop_name, features, target, seed_var, price_var, alpha=1.0):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize and fit the Lasso regression model
    model = Lasso(alpha=alpha)
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Lasso Regression with alpha {alpha}):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model with Lasso regression
for crop, info in crops_info.items():
    train_crop_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'], alpha=1.0)
# Out:
# Model for Wheat (Lasso Regression with alpha 1.0):
# Mean Squared Error: 41958016.99120002
# R^2 Score: -1.0267805706112343
# Mean Absolute Error (MAE): 5235.2449496727995
# ---
# Model for Oats (Lasso Regression with alpha 1.0):
# Mean Squared Error: 1181738.4075096513
# R^2 Score: -0.11182120362312475
# Mean Absolute Error (MAE): 898.9254907621446
# ---
# Model for Barley (Lasso Regression with alpha 1.0):
# Mean Squared Error: 3858168.5514005297
# R^2 Score: -1.411237232635747
# Mean Absolute Error (MAE): 1698.8379980448997
# ---
# Model for Flax (Lasso Regression with alpha 1.0):
# Mean Squared Error: 134325.6196510527
# R^2 Score: -2.3996310023179888
# Mean Absolute Error (MAE): 253.78410012503696
# ---
# Model for Canola (Lasso Regression with alpha 1.0):
# Mean Squared Error: 5536990.977082157
# R^2 Score: 0.7780978033769548
# Mean Absolute Error (MAE): 2021.524846528849
# ---
# Model for Lentils (Lasso Regression with alpha 1.0):
# Mean Squared Error: 333171.5469943665
# R^2 Score: 0.504964695577133
# Mean Absolute Error (MAE): 458.84225333666416
# ---
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.029e+06, tolerance: 5.836e+03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.752e+05, tolerance: 1.207e+03
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# $$ Random Forest Regressor Model  $$

# %% [markdown]
# Random Forest is a popular machine learning model for several reasons:
#
# Robustness to Overfitting:
# Random Forest is an ensemble learning method that builds multiple decision trees during training and merges their predictions. This averaging process helps reduce overfitting compared to single decision trees, making it more robust.
# Handling Non-linearity:
# Random Forest can capture complex relationships in the data without requiring a linear assumption. It can model non-linear patterns effectively, which is particularly useful in agricultural data where relationships may not be straightforward.
# Feature Importance:
# Random Forest provides insights into feature importance, allowing practitioners to understand which variables contribute most to predictions. This can aid in identifying key factors affecting crop production.
# Flexibility with Data Types:
# The model can handle both numerical and categorical data, making it versatile for various datasets encountered in agricultural applications.
# Tuning and Customization:
# The n_estimators parameter allows you to control the number of trees in the forest, which can be tuned to improve model performance. More trees can lead to better accuracy but may also increase computation time.
# Good Performance with Default Settings:
# Random Forest often performs well with minimal hyperparameter tuning, making it a good starting point for predictive modeling.
#
# In summary, Random Forest is considered a strong option for regression tasks, including crop production modeling, due to its robustness, ability to handle non-linear relationships, feature importance insights, and versatility with different data types. Its ensemble nature helps mitigate overfitting, making it suitable for complex datasets commonly found in agricultural research and applications.

# %%
# Function to plot feature importance
def plot_feature_importance(crop_name, features, target, ax):
    X = data[features]
    y = data[target]

    # Fit Random Forest Regressor
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X, y)

    # Get feature importances
    importances = model.feature_importances_
    
    # Create a DataFrame for visualization
    importance_df = pd.DataFrame({'Feature': features, 'Importance': importances})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    # Plotting
    ax.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
    ax.set_xlabel('Importance')
    ax.set_title(f'Feature Importance for {crop_name}')

# Create subplots to plot two graphs in a row
fig, axs = plt.subplots(2, 3, figsize=(18, 10))  # 2 rows, 3 columns

# Loop through all crops and plot feature importance
crop_names = list(crops_info.keys())
for i, crop in enumerate(crop_names):
    ax = axs[i // 3, i % 3]  # Determine the correct subplot
    plot_feature_importance(crop, crops_info[crop]['features'], crops_info[crop]['target'], ax)

plt.tight_layout()
plt.show()

# %%
def train_crop_model(train, test, crop_name, features, target, seed_var, price_var, n_estimators=100, random_state=42):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize and fit the Random Forest regression model
    model = RandomForestRegressor(n_estimators=n_estimators, random_state=random_state)
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Random Forest with {n_estimators} trees):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model with Random Forest regression
for crop, info in crops_info.items():
    train_crop_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'], n_estimators=100)
# Out:
# Model for Wheat (Random Forest with 100 trees):
# Mean Squared Error: 12230457.680106672
# R^2 Score: 0.4092081615553447
# Mean Absolute Error (MAE): 3209.9582819151483
# ---
# Model for Oats (Random Forest with 100 trees):
# Mean Squared Error: 898341.3380847154
# R^2 Score: 0.1548087618827776
# Mean Absolute Error (MAE): 800.7514299759597
# ---
# Model for Barley (Random Forest with 100 trees):
# Mean Squared Error: 1588038.0255017611
# R^2 Score: 0.007524849441527981
# Mean Absolute Error (MAE): 1039.9545807053314
# ---
# Model for Flax (Random Forest with 100 trees):
# Mean Squared Error: 20863.991823890563
# R^2 Score: 0.4719557324889547
# Mean Absolute Error (MAE): 125.40921393987492
# ---
# Model for Canola (Random Forest with 100 trees):
# Mean Squared Error: 2487740.79885397
# R^2 Score: 0.9003005151752346
# Mean Absolute Error (MAE): 1333.050252249113
# ---
# Model for Lentils (Random Forest with 100 trees):
# Mean Squared Error: 154270.27374875528
# R^2 Score: 0.7707810507302851
# Mean Absolute Error (MAE): 322.72717178136133
# ---

# %% [markdown]
# $$ SVR  $$

# %% [markdown]
# Why SVR is also Considered:
#
# Robustness to Outliers: SVR uses an epsilon-insensitive loss function, making it less sensitive to outliers and more focused on relevant data points.
# Effective in High Dimensions: It performs well in high-dimensional datasets, where the number of features exceeds the number of observations.
# Flexibility with Kernels: SVR can capture complex, non-linear relationships through different kernel functions, allowing for customization based on data characteristics.
# Generalization: The model aims to balance training error and complexity, ensuring good performance on unseen data.
# Control Over Complexity: SVR provides parameters to manage the trade-off between fitting the data closely and maintaining simplicity.
#
# Kernel Functions in SVR:
#
# Linear Kernel: Captures linear relationships, suitable for linearly separable data.
# Polynomial Kernel: Models polynomial relationships by introducing polynomial terms, useful for more complex interactions.
# Radial Basis Function (RBF) Kernel: Handles non-linear relationships effectively by measuring distance in an infinite-dimensional space.
#
#
# In this project, we experiment with all three kernel types—linear, polynomial, and RBF—to identify which best captures the relationships in the crop production data, enhancing the model's predictive performance.

# %%
def train_crop_model_svr(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Scale the features
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()

    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
    y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

    # Initialize and fit the SVR model
    model = SVR(kernel='linear')  # You can change the kernel if needed
    model.fit(X_train_scaled, y_train_scaled)

    # Make predictions
    y_pred_scaled = model.predict(X_test_scaled)

    # Inverse transform the predictions to original scale
    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (SVR):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model using SVR
for crop, info in crops_info.items():
    train_crop_model_svr(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
# Out:
# Model for Wheat (SVR):
# Mean Squared Error: 5533221.454999709
# R^2 Score: 0.73271792753612
# Mean Absolute Error (MAE): 1541.7499107564631
# ---
# Model for Oats (SVR):
# Mean Squared Error: 1237766.9231386236
# R^2 Score: -0.1645348086713827
# Mean Absolute Error (MAE): 967.1370102011224
# ---
# Model for Barley (SVR):
# Mean Squared Error: 3238372.5855646385
# R^2 Score: -1.0238837281035424
# Mean Absolute Error (MAE): 1415.120758195429
# ---
# Model for Flax (SVR):
# Mean Squared Error: 122396.5812906947
# R^2 Score: -2.097720400728623
# Mean Absolute Error (MAE): 255.23291793543552
# ---
# Model for Canola (SVR):
# Mean Squared Error: 7688673.443691373
# R^2 Score: 0.6918662982594428
# Mean Absolute Error (MAE): 2119.341398213229
# ---
# Model for Lentils (SVR):
# Mean Squared Error: 155616.7463284275
# R^2 Score: 0.7687804253185768
# Mean Absolute Error (MAE): 359.17395173552154
# ---

# %%
def train_crop_model_svr(data, crop_name, features, target, seed_var, price_var):
    # Define features and target variable
    X = data[features + [seed_var, price_var]]
    y = data[target]

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Scale the features
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()

    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
    y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

    # Initialize and fit the SVR model
    model = SVR(kernel='poly') 
    model.fit(X_train_scaled, y_train_scaled)

    # Make predictions
    y_pred_scaled = model.predict(X_test_scaled)

    # Inverse transform the predictions to original scale
    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (SVR):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model using SVR
for crop, info in crops_info.items():
    train_crop_model_svr(data, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
# Out:
# Model for Wheat (SVR):
# Mean Squared Error: 47660486.52030362
# R^2 Score: -2.1195186200661897
# Mean Absolute Error (MAE): 4558.559915485396
# ---
# Model for Oats (SVR):
# Mean Squared Error: 451294.90845468256
# R^2 Score: 0.5037179219414072
# Mean Absolute Error (MAE): 554.1129401253518
# ---
# Model for Barley (SVR):
# Mean Squared Error: 3168149.0214849603
# R^2 Score: -0.5019888436581306
# Mean Absolute Error (MAE): 1639.7850334482823
# ---
# Model for Flax (SVR):
# Mean Squared Error: 44839.463648446916
# R^2 Score: -0.3341014787643264
# Mean Absolute Error (MAE): 168.68485365278877
# ---
# Model for Canola (SVR):
# Mean Squared Error: 118124490.41488107
# R^2 Score: -4.151763633739801
# Mean Absolute Error (MAE): 5800.099373159669
# ---
# Model for Lentils (SVR):
# Mean Squared Error: 1605531.1084235115
# R^2 Score: -1.826526978544261
# Mean Absolute Error (MAE): 730.142417681786
# ---

# %%
def train_crop_model_svr(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [price_var, seed_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [price_var, seed_var]]
    y_test = test[target]

    # Scale the features
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()

    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
    y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

    # Initialize and fit the SVR model
    svm_model = SVR(kernel='rbf')  
    svm_model.fit(X_train_scaled, y_train_scaled)

    # Make predictions
    y_pred_scaled = svm_model.predict(X_test_scaled)

    # Inverse transform the predictions to original scale
    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation results
    print(f'Model for {crop_name} (SVR):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score (analogous to accuracy): {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

# Iterate over each crop and train the model using SVR
for crop, info in crops_info.items():
    train_crop_model_svr(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
# Out:
# Model for Wheat (SVR):
# Mean Squared Error: 16566531.573290626
# R^2 Score (analogous to accuracy): 0.1997542609746037
# Mean Absolute Error (MAE): 3265.3810347318104
# ---
# Model for Oats (SVR):
# Mean Squared Error: 1148642.2971448964
# R^2 Score (analogous to accuracy): -0.08068321485407903
# Mean Absolute Error (MAE): 863.0579901397126
# ---
# Model for Barley (SVR):
# Mean Squared Error: 239455.85793149294
# R^2 Score (analogous to accuracy): 0.8503474193714117
# Mean Absolute Error (MAE): 433.9181636545045
# ---
# Model for Flax (SVR):
# Mean Squared Error: 38885.236880995
# R^2 Score (analogous to accuracy): 0.015858202057633886
# Mean Absolute Error (MAE): 189.06267744042765
# ---
# Model for Canola (SVR):
# Mean Squared Error: 8788738.476508977
# R^2 Score (analogous to accuracy): 0.6477797450718366
# Mean Absolute Error (MAE): 2505.2983452738736
# ---
# Model for Lentils (SVR):
# Mean Squared Error: 348438.6041530637
# R^2 Score (analogous to accuracy): 0.4822804887282067
# Mean Absolute Error (MAE): 566.8035261903526
# ---

# %% [markdown]
# $$ Hyperparameter tuning: Random Forest and Svr (rbf) $$

# %%
def train_crop_model(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize the Random Forest model
    model = RandomForestRegressor(random_state=42)

    # Fit the model
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Random Forest):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_rf = []

# Iterate over each crop and train the model with Random Forest regression
for crop, info in crops_info.items():
    r2_rf = train_crop_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_rf.append({'Crop': crop, 'Model': 'Random Forest', 'R^2 Score': r2_rf})

# Convert the results into a DataFrame
results_rf_df = pd.DataFrame(results_rf)

# Display the DataFrame
print(results_rf_df)
# Out:
# Model for Wheat (Random Forest):
# Mean Squared Error: 12284305.070873026
# R^2 Score: 0.40660706519261025
# Mean Absolute Error (MAE): 3144.659081915149
# ---
# Model for Oats (Random Forest):
# Mean Squared Error: 893436.8449338523
# R^2 Score: 0.1594230821447764
# Mean Absolute Error (MAE): 805.3504299759595
# ---
# Model for Barley (Random Forest):
# Mean Squared Error: 1547016.959682618
# R^2 Score: 0.03316175978066138
# Mean Absolute Error (MAE): 1059.5697807053325
# ---
# Model for Flax (Random Forest):
# Mean Squared Error: 22118.59333086093
# R^2 Score: 0.440203173373789
# Mean Absolute Error (MAE): 130.4324139398749
# ---
# Model for Canola (Random Forest):
# Mean Squared Error: 2782763.9535548305
# R^2 Score: 0.8884770741846769
# Mean Absolute Error (MAE): 1504.164252249117
# ---
# Model for Lentils (Random Forest):
# Mean Squared Error: 145217.27374024672
# R^2 Score: 0.7842322432333113
# Mean Absolute Error (MAE): 311.78136216057976
# ---
#       Crop          Model  R^2 Score
# 0    Wheat  Random Forest   0.406607
# 1     Oats  Random Forest   0.159423
# 2   Barley  Random Forest   0.033162
# 3     Flax  Random Forest   0.440203
# 4   Canola  Random Forest   0.888477
# 5  Lentils  Random Forest   0.784232

# %%
def train_grid_search_model(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Set the parameter grid for hyperparameter tuning
    param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }

    # Initialize the Random Forest model
    model = RandomForestRegressor(random_state=42)

    # Initialize GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                               scoring='neg_mean_squared_error', cv=5, n_jobs=-1, verbose=2)

    # Fit the model using GridSearchCV
    grid_search.fit(X_train, y_train)

    # Get the best estimator
    best_model = grid_search.best_estimator_

    # Make predictions with the best model
    y_pred = best_model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Grid Search - Best Params: {grid_search.best_params_}):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_gs = []

# Iterate over each crop and train the model with Grid Search
for crop, info in crops_info.items():
    r2_gs = train_grid_search_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_gs.append({'Crop': crop, 'Model': 'Grid Search', 'R^2 Score': r2_gs})

# Convert the results into a DataFrame
results_gs_df = pd.DataFrame(results_gs)

# Display the DataFrame
print(results_gs_df)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Model for Wheat (Grid Search - Best Params: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}):
# Mean Squared Error: 8901574.041694526
# R^2 Score: 0.5700097714496926
# Mean Absolute Error (MAE): 2686.627597168238
# ---
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Model for Oats (Grid Search - Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}):
# Mean Squared Error: 925120.2421978522
# R^2 Score: 0.1296142237230853
# Mean Absolute Error (MAE): 821.9980046959278
# ---
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Model for Barley (Grid Search - Best Params: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}):
# Mean Squared Error: 1144579.232147899
# R^2 Score: 0.28467301946805523
# Mean Absolute Error (MAE): 846.3796381248636
# ---
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Model for Flax (Grid Search - Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}):
# Mean Squared Error: 20571.88425378347
# R^2 Score: 0.47934864795755694
# Mean Absolute Error (MAE): 128.51031393987503
# ---
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Model for Canola (Grid Search - Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}):
# Mean Squared Error: 3003936.229711183
# R^2 Score: 0.8796133042933493
# Mean Absolute Error (MAE): 1452.646552249113
# ---
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Model for Lentils (Grid Search - Best Params: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}):
# Mean Squared Error: 177938.8474732354
# R^2 Score: 0.7356136431150389
# Mean Absolute Error (MAE): 363.0075880180218
# ---
#       Crop        Model  R^2 Score
# 0    Wheat  Grid Search   0.570010
# 1     Oats  Grid Search   0.129614
# 2   Barley  Grid Search   0.284673
# 3     Flax  Grid Search   0.479349
# 4   Canola  Grid Search   0.879613
# 5  Lentils  Grid Search   0.735614

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV

def train_random_search_model(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Set the parameter distribution for hyperparameter tuning
    param_dist = {
        'n_estimators': np.random.randint(50, 300, size=10),  # Random integers between 50 and 300
        'max_depth': [None] + list(np.random.randint(10, 50, size=10)),  # Random depths
        'min_samples_split': np.random.randint(2, 11, size=10),  # Random integers between 2 and 10
        'min_samples_leaf': np.random.randint(1, 5, size=10)  # Random integers between 1 and 4
    }

    # Initialize the Random Forest model
    model = RandomForestRegressor(random_state=42)

    # Initialize RandomizedSearchCV
    random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist, 
                                       scoring='neg_mean_squared_error', n_iter=50, 
                                       cv=5, n_jobs=-1, verbose=2, random_state=42)

    # Fit the model using RandomizedSearchCV
    random_search.fit(X_train, y_train)

    # Get the best estimator
    best_model = random_search.best_estimator_

    # Make predictions with the best model
    y_pred = best_model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Random Search - Best Params: {random_search.best_params_}):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_rs = []

# Iterate over each crop and train the model with Random Search
for crop, info in crops_info.items():
    r2_rs = train_random_search_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_rs.append({'Crop': crop, 'Model': 'Random Search', 'R^2 Score': r2_rs})

# Convert the results into a DataFrame
results_rs_df = pd.DataFrame(results_rs)

# Display the DataFrame
print(results_rs_df)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Model for Wheat (Random Search - Best Params: {'n_estimators': 121, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_depth': None}):
# Mean Squared Error: 9213422.831490645
# R^2 Score: 0.554945926362353
# Mean Absolute Error (MAE): 2575.7411699191616
# ---
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Model for Oats (Random Search - Best Params: {'n_estimators': 209, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 23}):
# Mean Squared Error: 918011.871288755
# R^2 Score: 0.13630202996660667
# Mean Absolute Error (MAE): 820.8038473533395
# ---
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Model for Barley (Random Search - Best Params: {'n_estimators': 159, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_depth': 38}):
# Mean Squared Error: 1128656.5479482848
# R^2 Score: 0.29462420964394154
# Mean Absolute Error (MAE): 843.623800623783
# ---
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Model for Flax (Random Search - Best Params: {'n_estimators': 254, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_depth': 47}):
# Mean Squared Error: 17806.326431225723
# R^2 Score: 0.5493418193026383
# Mean Absolute Error (MAE): 112.36268065142242
# ---
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Model for Canola (Random Search - Best Params: {'n_estimators': 203, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 24}):
# Mean Squared Error: 3019726.443530426
# R^2 Score: 0.8789804907044992
# Mean Absolute Error (MAE): 1449.663130081625
# ---
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Model for Lentils (Random Search - Best Params: {'n_estimators': 184, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_depth': 12}):
# Mean Squared Error: 180001.3051309613
# R^2 Score: 0.7325491876906118
# Mean Absolute Error (MAE): 366.4102632626529
# ---
#       Crop          Model  R^2 Score
# 0    Wheat  Random Search   0.554946
# 1     Oats  Random Search   0.136302
# 2   Barley  Random Search   0.294624
# 3     Flax  Random Search   0.549342
# 4   Canola  Random Search   0.878980
# 5  Lentils  Random Search   0.732549

# %%
# Combine the three results DataFrames
combined_results_df = pd.concat([results_rf_df, results_gs_df, results_rs_df], ignore_index=True)

# Display the combined DataFrame
print(combined_results_df)
# Out:
#        Crop          Model  R^2 Score
# 0     Wheat  Random Forest   0.409208
# 1      Oats  Random Forest   0.154809
# 2    Barley  Random Forest   0.007525
# 3      Flax  Random Forest   0.471956
# 4    Canola  Random Forest   0.900301
# 5   Lentils  Random Forest   0.770781
# 6     Wheat    Grid Search   0.570010
# 7      Oats    Grid Search   0.129614
# 8    Barley    Grid Search   0.284673
# 9      Flax    Grid Search   0.479349
# 10   Canola    Grid Search   0.879613
# 11  Lentils    Grid Search   0.735614
# 12    Wheat  Random Search   0.554946
# 13     Oats  Random Search   0.136302
# 14   Barley  Random Search   0.294624
# 15     Flax  Random Search   0.549342
# 16   Canola  Random Search   0.878980
# 17  Lentils  Random Search   0.732549

# %%
# Restructure the combined DataFrame for plotting
pivot_results_df = combined_results_df.pivot(index='Crop', columns='Model', values='R^2 Score')

# Reset the index to make 'Crop' a column again
pivot_results_df.reset_index(inplace=True)

# Display the pivoted DataFrame
print(pivot_results_df)
# Out:
# Model     Crop  Grid Search  Random Forest  Random Search
# 0       Barley     0.284673       0.007525       0.294624
# 1       Canola     0.879613       0.900301       0.878980
# 2         Flax     0.479349       0.471956       0.549342
# 3      Lentils     0.735614       0.770781       0.732549
# 4         Oats     0.129614       0.154809       0.136302
# 5        Wheat     0.570010       0.409208       0.554946

# %%
# Plotting the R² scores for each model
plt.figure(figsize=(12, 6))

for model in pivot_results_df.columns[1:]:  # Skip the first column (Crop)
    plt.plot(pivot_results_df['Crop'], pivot_results_df[model], marker='o', label=model)

plt.title('R² Scores for Different Crop Models')
plt.xlabel('Crop')
plt.ylabel('R² Score')
plt.xticks(rotation=45)  # Rotate crop names for better visibility
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
#        'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons', 'Nonres_Pat_App',
#        'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind', 'Wheat_Price',
#        'Wheat_Seed', 'Wheat_Prod', 'Oats_Price', 'Oats_Seed', 'Oats_Prod',
#        'Barley_Price', 'Barley_Seed', 'Barley_Prod', 'Flax_Price', 'Flax_Seed',
#        'Flax_Prod', 'Canola_Price', 'Canola_Seed', 'Canola_Prod',
#        'Lentils_Price', 'Lentils_Seed', 'Lentils_Prod', 'Total_Prod'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# Initialize the model
model = RandomForestRegressor(random_state=42)

# Define crops information with seed and price included
crops_info = {
    'Wheat': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Wheat_Seed', 'Wheat_Price'],
        'target': 'Wheat_Prod'
    },
    'Oats': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Oats_Seed', 'Oats_Price'],
        'target': 'Oats_Prod'
    },
    'Barley': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Barley_Seed', 'Barley_Price'],
        'target': 'Barley_Prod'
    },
    'Flax': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Flax_Seed', 'Flax_Price'],
        'target': 'Flax_Prod'
    },
    'Canola': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Canola_Seed', 'Canola_Price'],
        'target': 'Canola_Prod'
    },
    'Lentils': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Lentils_Seed', 'Lentils_Price'],
        'target': 'Lentils_Prod'
    }
}

# Determine the number of rows needed for 2 plots per row
num_crops = len(crops_info)
num_cols = 2  # Two plots per row
num_rows = (num_crops + 1) // num_cols  # Compute required rows

fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 6 * num_rows))

# Flatten axes if there's more than one row
if num_rows > 1:
    axes = axes.flatten()

# Loop through each crop
for i, (crop, info) in enumerate(crops_info.items()):
    # Select only relevant features for this crop
    X = data[info['features']]
    y = data[info['target']]

    # Initialize and fit RFE
    rfe = RFE(estimator=model, n_features_to_select=10)
    rfe.fit(X, y)

    # Get selected features and their importance
    selected_features = X.columns[rfe.support_]
    importance_values = rfe.estimator_.feature_importances_

    # Create DataFrame for feature importances
    importance_df = pd.DataFrame({
        'Feature': selected_features,
        'Importance': importance_values
    }).sort_values(by='Importance', ascending=False)

    # **PRINT important features for each crop**
    print(f"\nTop Features for {crop}:")
    print(importance_df.to_string(index=False))  # Print without the index

    # Plot in the corresponding subplot
    ax = axes[i] if num_rows > 1 else axes[i % num_cols]  # Adjust for single-row case
    ax.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
    ax.set_xlabel('Importance')
    ax.set_title(f'Feature Importance for {crop}')
    ax.invert_yaxis()  # Invert y-axis for readability

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# Top Features for Wheat:
#               Feature  Importance
#            Population    0.228317
#     Veg_Greeness_Rate    0.207163
# Agric_Employment_Rate    0.119735
#             Farm_Area    0.100746
#        Fertlizer_Cons    0.096278
#        Nonres_Pat_App    0.070080
#            Wheat_Seed    0.061342
#              Max_Temp    0.046883
#             Green_Ind    0.037316
#           Wheat_Price    0.032139
#
# Top Features for Oats:
#           Feature  Importance
#    Fertlizer_Cons    0.281202
#          Ave_Temp    0.165103
#       Res_Pat_App    0.120476
#    Nonres_Pat_App    0.099987
#        Population    0.086410
#          Max_Temp    0.055772
#        Oats_Price    0.052218
#     Precipitation    0.049170
# Veg_Greeness_Rate    0.048192
#          Min_Temp    0.041469
#
# Top Features for Barley:
#        Feature  Importance
#    Res_Pat_App    0.263177
#    Barley_Seed    0.258807
# Fertlizer_Cons    0.106798
#  Precipitation    0.078940
#   Barley_Price    0.066801
# Nonres_Pat_App    0.060184
#      Green_Ind    0.057296
#       Max_Temp    0.047459
#       Min_Temp    0.040662
#       Ave_Temp    0.019877
#
# Top Features for Flax:
#               Feature  Importance
#             Farm_Area    0.578657
#             Flax_Seed    0.091595
#            Flax_Price    0.069616
#              Min_Temp    0.055330
#             Green_Ind    0.041873
#        Fertlizer_Cons    0.037338
#        Nonres_Pat_App    0.033902
# Agric_Employment_Rate    0.033307
#              Ave_Temp    0.029575
#         Precipitation    0.028808
#
# Top Features for Canola:
#               Feature  Importance
#            Population    0.229500
#           Canola_Seed    0.189372
#             Farm_Area    0.142787
#        Fertlizer_Cons    0.136208
#        Nonres_Pat_App    0.128505
# Agric_Employment_Rate    0.061173
#     Veg_Greeness_Rate    0.037039
#          Canola_Price    0.035054
#             Green_Ind    0.021470
#           Res_Pat_App    0.018891
#
# Top Features for Lentils:
#               Feature  Importance
#             Farm_Area    0.257891
#        Fertlizer_Cons    0.160720
# Agric_Employment_Rate    0.114209
#            Population    0.098134
#          Lentils_Seed    0.096737
#             Green_Ind    0.072046
#        Nonres_Pat_App    0.060997
#           Res_Pat_App    0.053159
#     Veg_Greeness_Rate    0.051340
#              Min_Temp    0.034768

# %%
crops_info = {
    'Wheat': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Wheat_Seed', 'Wheat_Price'],
        'target': 'Wheat_Prod',
        'seed_var': 'Wheat_Seed',
        'price_var': 'Wheat_Price'
    },
    'Oats': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Oats_Seed', 'Oats_Price'],
        'target': 'Oats_Prod',
        'seed_var': 'Oats_Seed',
        'price_var': 'Oats_Price'
    },
    'Barley': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Barley_Seed', 'Barley_Price'],
        'target': 'Barley_Prod',
        'seed_var': 'Barley_Seed',
        'price_var': 'Barley_Price'
    },
    'Flax': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Flax_Seed', 'Flax_Price'],
        'target': 'Flax_Prod',
        'seed_var': 'Flax_Seed',
        'price_var': 'Flax_Price'
    },
    'Canola': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Canola_Seed', 'Canola_Price'],
        'target': 'Canola_Prod',
        'seed_var': 'Canola_Seed',
        'price_var': 'Canola_Price'
    },
    'Lentils': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind',
                     'Lentils_Seed', 'Lentils_Price'],
        'target': 'Lentils_Prod',
        'seed_var': 'Lentils_Seed',
        'price_var': 'Lentils_Price'
    }
}

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Function to select important features and train the model
def train_crop_model(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize the Random Forest model
    model = RandomForestRegressor(random_state=42)

    # Fit the model to determine feature importance
    model.fit(X_train, y_train)

    # Get feature importances
    feature_importance = pd.DataFrame({
        'Feature': X_train.columns,
        'Importance': model.feature_importances_
    }).sort_values(by='Importance', ascending=False)

    # **Filter features with importance > 0.05**
    selected_features = feature_importance[feature_importance['Importance'] > 0.05]['Feature'].tolist()

    # Ensure we don't drop both seed and price variables
    if seed_var not in selected_features:
        selected_features.append(seed_var)
    if price_var not in selected_features:
        selected_features.append(price_var)

    print(f"\nSelected Features for {crop_name}: {selected_features}")

    # Train the model again with only selected features
    X_train_filtered = train[selected_features]
    X_test_filtered = test[selected_features]

    # Train the final model with important features
    featured_rf = RandomForestRegressor(random_state=42)
    featured_rf.fit(X_train_filtered, y_train)

    # Make predictions
    y_pred = featured_rf.predict(X_test_filtered)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (Random Forest):')
    print(f'Mean Squared Error: {mse:.4f}')
    print(f'R^2 Score: {r2:.4f}')
    print(f'Mean Absolute Error (MAE): {mae:.4f}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_rf = []

# Iterate over each crop and train the model with selected features
for crop, info in crops_info.items():
    r2_rf = train_crop_model(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_rf.append({'Crop': crop, 'Model': 'Random Forest (featured_rf)', 'R^2 Score': r2_rf})

# Convert the results into a DataFrame
featured_rf = pd.DataFrame(results_rf)

# Display the DataFrame
print(featured_rf)
# Out:
# Selected Features for Wheat: ['Population', 'Veg_Greeness_Rate', 'Agric_Employment_Rate', 'Farm_Area', 'Green_Ind', 'Res_Pat_App', 'Wheat_Price', 'Fertlizer_Cons', 'Wheat_Seed']
# Model for Wheat (Random Forest):
# Mean Squared Error: 11743508.9459
# R^2 Score: 0.4327
# Mean Absolute Error (MAE): 3024.4553
# ---
#
# Selected Features for Oats: ['Res_Pat_App', 'Ave_Temp', 'Fertlizer_Cons', 'Min_Temp', 'Green_Ind', 'Nonres_Pat_App', 'Oats_Seed', 'Oats_Price']
# Model for Oats (Random Forest):
# Mean Squared Error: 891372.2405
# R^2 Score: 0.1614
# Mean Absolute Error (MAE): 810.6640
# ---
#
# Selected Features for Barley: ['Res_Pat_App', 'Barley_Seed', 'Precipitation', 'Barley_Seed', 'Barley_Price', 'Barley_Price', 'Agric_Employment_Rate', 'Fertlizer_Cons']
# Model for Barley (Random Forest):
# Mean Squared Error: 1718040.2737
# R^2 Score: -0.0737
# Mean Absolute Error (MAE): 1085.1348
# ---
#
# Selected Features for Flax: ['Farm_Area', 'Flax_Seed', 'Flax_Seed', 'Green_Ind', 'Agric_Employment_Rate', 'Population', 'Min_Temp', 'Flax_Price']
# Model for Flax (Random Forest):
# Mean Squared Error: 21271.3506
# R^2 Score: 0.4616
# Mean Absolute Error (MAE): 132.8260
# ---
#
# Selected Features for Canola: ['Farm_Area', 'Population', 'Canola_Seed', 'Agric_Employment_Rate', 'Nonres_Pat_App', 'Canola_Price', 'Canola_Seed', 'Canola_Price', 'Veg_Greeness_Rate', 'Fertlizer_Cons']
# Model for Canola (Random Forest):
# Mean Squared Error: 2836009.1964
# R^2 Score: 0.8863
# Mean Absolute Error (MAE): 1437.2349
# ---
#
# Selected Features for Lentils: ['Agric_Employment_Rate', 'Population', 'Lentils_Seed', 'Farm_Area', 'Veg_Greeness_Rate', 'Fertlizer_Cons', 'Nonres_Pat_App', 'Lentils_Price']
# Model for Lentils (Random Forest):
# Mean Squared Error: 136265.9048
# R^2 Score: 0.7975
# Mean Absolute Error (MAE): 290.3154
# ---
#       Crop                        Model  R^2 Score
# 0    Wheat  Random Forest (featured_rf)   0.432730
# 1     Oats  Random Forest (featured_rf)   0.161366
# 2   Barley  Random Forest (featured_rf)  -0.073723
# 3     Flax  Random Forest (featured_rf)   0.461646
# 4   Canola  Random Forest (featured_rf)   0.886343
# 5  Lentils  Random Forest (featured_rf)   0.797532

# %%
# Assuming results_rf_df and featured_rf are already generated

# Concatenate the results from both models
combined_results_df = pd.concat([results_rf_df, featured_rf], ignore_index=True)

# Print the combined DataFrame
print(combined_results_df)
# Out:
#        Crop                        Model  R^2 Score
# 0     Wheat                Random Forest   0.406607
# 1      Oats                Random Forest   0.159423
# 2    Barley                Random Forest   0.033162
# 3      Flax                Random Forest   0.440203
# 4    Canola                Random Forest   0.888477
# 5   Lentils                Random Forest   0.784232
# 6     Wheat  Random Forest (featured_rf)   0.432730
# 7      Oats  Random Forest (featured_rf)   0.161366
# 8    Barley  Random Forest (featured_rf)  -0.073723
# 9      Flax  Random Forest (featured_rf)   0.461646
# 10   Canola  Random Forest (featured_rf)   0.886343
# 11  Lentils  Random Forest (featured_rf)   0.797532

# %%
import matplotlib.pyplot as plt

# Reformat the DataFrame to have one row per crop and one column for each model
combined_results_df = combined_results_df.pivot(index='Crop', columns='Model', values='R^2 Score')

# Plotting the line graph
plt.figure(figsize=(10, 6))

# Plot lines for each model
for model in combined_results_df.columns:
    plt.plot(combined_results_df.index, combined_results_df[model], marker='o', label=model)

# Adding labels and title
plt.xlabel('Crop')
plt.ylabel('R^2 Score')
plt.title('Comparison of R^2 Scores for Random Forest Models')
plt.legend()

# Show plot
plt.xticks(rotation=45)  # Rotate crop names for readability
plt.tight_layout()
plt.show()

# %% [markdown]
# $$ XG Boost $$

# %%
# Define crops information
crops_info = {
    'Wheat': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Wheat_Prod',
        'seed_var': 'Wheat_Seed',
        'price_var': 'Wheat_Price'
    },
    'Oats': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Oats_Prod',
        'seed_var': 'Oats_Seed',
        'price_var': 'Oats_Price'
    },
    'Barley': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Barley_Prod',
        'seed_var': 'Barley_Seed',
        'price_var': 'Barley_Price'
    },
    'Flax': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Flax_Prod',
        'seed_var': 'Flax_Seed',
        'price_var': 'Flax_Price'
    },
    'Canola': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Canola_Prod',
        'seed_var': 'Canola_Seed',
        'price_var': 'Canola_Price'
    },
    'Lentils': {
        'features': ['Farm_Area', 'Agric_Employment_Rate', 'Population', 'Precipitation',
                     'Min_Temp', 'Max_Temp', 'Ave_Temp', 'Fertlizer_Cons',
                     'Nonres_Pat_App', 'Res_Pat_App', 'Veg_Greeness_Rate', 'Green_Ind'],
        'target': 'Lentils_Prod',
        'seed_var': 'Lentils_Seed',
        'price_var': 'Lentils_Price'
    }
}

# %%
def train_crop_model_xgboost(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize the XGBoost model
    model = XGBRegressor(random_state=42)

    # Fit the model
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (XGBoost):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_xgboost = []

# Iterate over each crop and train the model with XGBoost regression
for crop, info in crops_info.items():
    r2_xgboost = train_crop_model_xgboost(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_xgboost.append({'Crop': crop, 'Model': 'XGBoost', 'R^2 Score': r2_xgboost})

# Convert the results into a DataFrame
results_xgboost_df = pd.DataFrame(results_xgboost)

# Display the DataFrame
print(results_xgboost_df)
# Out:
# Model for Wheat (XGBoost):
# Mean Squared Error: 15754827.91159612
# R^2 Score: 0.23896357849219418
# Mean Absolute Error (MAE): 3075.546835040158
# ---
# Model for Oats (XGBoost):
# Mean Squared Error: 788320.9543930583
# R^2 Score: 0.25831982206479775
# Mean Absolute Error (MAE): 745.9015998978339
# ---
# Model for Barley (XGBoost):
# Mean Squared Error: 3542244.9709313423
# R^2 Score: -1.2137946663646657
# Mean Absolute Error (MAE): 1595.2528721115855
# ---
# Model for Flax (XGBoost):
# Mean Squared Error: 15429.202009227141
# R^2 Score: 0.6095041762855213
# Mean Absolute Error (MAE): 101.48738166448416
# ---
# Model for Canola (XGBoost):
# Mean Squared Error: 5152567.676909881
# R^2 Score: 0.7935040727919469
# Mean Absolute Error (MAE): 2003.2335272491157
# ---
# Model for Lentils (XGBoost):
# Mean Squared Error: 48311.84942430337
# R^2 Score: 0.9282169461865958
# Mean Absolute Error (MAE): 163.38081165420238
# ---
#       Crop    Model  R^2 Score
# 0    Wheat  XGBoost   0.238964
# 1     Oats  XGBoost   0.258320
# 2   Barley  XGBoost  -1.213795
# 3     Flax  XGBoost   0.609504
# 4   Canola  XGBoost   0.793504
# 5  Lentils  XGBoost   0.928217

# %% [markdown]
# $$ GBM $$

# %%
def train_crop_model_gbm(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize the GBM model
    model = GradientBoostingRegressor(random_state=42)

    # Fit the model
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (GBM):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_gbm = []

# Iterate over each crop and train the model with GBM regression
for crop, info in crops_info.items():
    r2_gbm = train_crop_model_gbm(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_gbm.append({'Crop': crop, 'Model': 'GBM', 'R^2 Score': r2_gbm})

# Convert the results into a DataFrame
results_gbm_df = pd.DataFrame(results_gbm)

# Display the DataFrame
print(results_gbm_df)
# Out:
# Model for Wheat (GBM):
# Mean Squared Error: 18714375.923783116
# R^2 Score: 0.09600271334573707
# Mean Absolute Error (MAE): 3663.0484524782414
# ---
# Model for Oats (GBM):
# Mean Squared Error: 618845.083900312
# R^2 Score: 0.4177687027298559
# Mean Absolute Error (MAE): 683.010012365592
# ---
# Model for Barley (GBM):
# Mean Squared Error: 2227950.4437787025
# R^2 Score: -0.39240082203159443
# Mean Absolute Error (MAE): 1196.1722586685628
# ---
# Model for Flax (GBM):
# Mean Squared Error: 16547.216425497263
# R^2 Score: 0.5812084834723108
# Mean Absolute Error (MAE): 120.14397954962752
# ---
# Model for Canola (GBM):
# Mean Squared Error: 1284621.2381973355
# R^2 Score: 0.9485171141212833
# Mean Absolute Error (MAE): 988.1328272732353
# ---
# Model for Lentils (GBM):
# Mean Squared Error: 128146.2430418598
# R^2 Score: 0.8095968428061884
# Mean Absolute Error (MAE): 305.9682695150634
# ---
#       Crop Model  R^2 Score
# 0    Wheat   GBM   0.096003
# 1     Oats   GBM   0.417769
# 2   Barley   GBM  -0.392401
# 3     Flax   GBM   0.581208
# 4   Canola   GBM   0.948517
# 5  Lentils   GBM   0.809597

# %% [markdown]
# $$ Light GBM $$

# %%
from lightgbm import LGBMRegressor

# %%
def train_crop_model_lgbm(train, test, crop_name, features, target, seed_var, price_var):
    # Define features and target variable for training
    X_train = train[features + [seed_var, price_var]]
    y_train = train[target]

    # Define features and target variable for testing
    X_test = test[features + [seed_var, price_var]]
    y_test = test[target]

    # Initialize the LightGBM model
    model = LGBMRegressor(min_data_in_leaf=1, min_data_in_bin=1, random_state=42)

    # Fit the model
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Print evaluation metrics
    print(f'Model for {crop_name} (LightGBM):')
    print(f'Mean Squared Error: {mse}')
    print(f'R^2 Score: {r2}')
    print(f'Mean Absolute Error (MAE): {mae}')
    print('---')

    return r2  # Return the R^2 score

# Initialize a list to store results
results_lgbm = []

# Iterate over each crop and train the model with LightGBM regression
for crop, info in crops_info.items():
    r2_lgbm = train_crop_model_lgbm(train, test, crop, info['features'], info['target'], info['seed_var'], info['price_var'])
    results_lgbm.append({'Crop': crop, 'Model': 'LightGBM', 'R^2 Score': r2_lgbm})

# Convert the results into a DataFrame
results_lgbm_df = pd.DataFrame(results_lgbm)

# Display the DataFrame
print(results_lgbm_df)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005993 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 20, number of used features: 14
# [LightGBM] [Info] Start training from score 22633.829883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Model for Wheat (LightGBM):
# Mean Squared Error: 29945802.606445722
# R^2 Score: -0.44653096705768736
# Mean Absolute Error (MAE): 4344.2811920480835
# ---
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000369 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 20, number of used features: 14
# [LightGBM] [Info] Start training from score 3354.579993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Model for Oats (LightGBM):
# Mean Squared Error: 159476.1158589676
# R^2 Score: 0.8499592414389644
# Mean Absolute Error (MAE): 344.33830813322373
# ---
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000019 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 20, number of used features: 14
# [LightGBM] [Info] Start training from score 9593.474878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Model for Barley (LightGBM):
# Mean Squared Error: 2999170.6401925227
# R^2 Score: -0.8743898350514161
# Mean Absolute Error (MAE): 1411.6527496874392
# ---
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 20, number of used features: 14
# [LightGBM] [Info] Start training from score 647.645001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Model for Flax (LightGBM):
# Mean Squared Error: 16823.797789573677
# R^2 Score: 0.5742085188905712
# Mean Absolute Error (MAE): 108.41671347871639
# ---
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000031 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 285
# [LightGBM] [Info] Number of data points in the train set: 20, number of used features: 14
# [LightGBM] [Info] Start training from score 13554.079858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Model for Canola (LightGBM):
# Mean Squared Error: 6747915.298071489
# R^2 Score: 0.7295684183943909
# Mean Absolute Error (MAE): 2143.371055003984
# ---
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 20, number of used features: 14
# [LightGBM] [Info] Start training from score 1596.312640
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# Model for Lentils (LightGBM):
# Mean Squared Error: 224746.62896141774
# R^2 Score: 0.6660653741605078
# Mean Absolute Error (MAE): 429.4172596439914
# ---
#       Crop     Model  R^2 Score
# 0    Wheat  LightGBM  -0.446531
# 1     Oats  LightGBM   0.849959
# 2   Barley  LightGBM  -0.874390
# 3     Flax  LightGBM   0.574209
# 4   Canola  LightGBM   0.729568
# 5  Lentils  LightGBM   0.666065

# %%
# Concatenate the results from both models
combined_results_df = pd.concat([results_rf_df, featured_rf,results_xgboost_df,results_gbm_df,results_lgbm_df], ignore_index=True)

# Print the combined DataFrame
print(combined_results_df)
# Out:
#        Crop                        Model  R^2 Score
# 0     Wheat                Random Forest   0.406607
# 1      Oats                Random Forest   0.159423
# 2    Barley                Random Forest   0.033162
# 3      Flax                Random Forest   0.440203
# 4    Canola                Random Forest   0.888477
# 5   Lentils                Random Forest   0.784232
# 6     Wheat  Random Forest (featured_rf)   0.432730
# 7      Oats  Random Forest (featured_rf)   0.161366
# 8    Barley  Random Forest (featured_rf)  -0.073723
# 9      Flax  Random Forest (featured_rf)   0.461646
# 10   Canola  Random Forest (featured_rf)   0.886343
# 11  Lentils  Random Forest (featured_rf)   0.797532
# 12    Wheat                      XGBoost   0.238964
# 13     Oats                      XGBoost   0.258320
# 14   Barley                      XGBoost  -1.213795
# 15     Flax                      XGBoost   0.609504
# 16   Canola                      XGBoost   0.793504
# 17  Lentils                      XGBoost   0.928217
# 18    Wheat                          GBM   0.096003
# 19     Oats                          GBM   0.417769
# 20   Barley                          GBM  -0.392401
# 21     Flax                          GBM   0.581208
# 22   Canola                          GBM   0.948517
# 23  Lentils                          GBM   0.809597
# 24    Wheat                     LightGBM  -0.446531
# 25     Oats                     LightGBM   0.849959
# 26   Barley                     LightGBM  -0.874390
# 27     Flax                     LightGBM   0.574209
# 28   Canola                     LightGBM   0.729568
# 29  Lentils                     LightGBM   0.666065

# %%
# Set the visual style
sns.set(style="whitegrid")

# Create a barplot
plt.figure(figsize=(14, 8))
sns.barplot(data=combined_results_df, x='Crop', y='R^2 Score', hue='Model', ci=None)

# Add titles and labels
plt.title('Model Performance by Crop', fontsize=16)
plt.xlabel('Crop', fontsize=14)
plt.ylabel('R² Score', fontsize=14)
plt.axhline(0, color='gray', linestyle='--')  # Add a horizontal line at y=0 for reference
plt.legend(title='Model', loc='upper left')
plt.xticks(rotation=45)

# Set y-axis limits and ticks
plt.ylim(-1, 1)  # Set limits from -1 to 1
plt.yticks([round(i * 0.1, 1) for i in range(-10, 11)])  # Set ticks from -1 to 1 in increments of 0.1

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17204\3370077554.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=combined_results_df, x='Crop', y='R^2 Score', hue='Model', ci=None)
